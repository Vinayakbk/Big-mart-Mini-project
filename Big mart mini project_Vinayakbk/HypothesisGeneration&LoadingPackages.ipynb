# %%
import numpy as np
import pandas as pd
data = pd.read_csv('Train.csv')
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
fig=plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(data['Item_Weight'], data['Item_Visibility'], color=['blue'])
plt.title('Cities')
plt.xlabel('Types')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns 
sns.boxplot(data['Item_Visibility']) 
sns.despine()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
test= data.groupby(['Item_Fat_Content','Outlet_Location_Type'])
test.size()
# Out:
# Item_Fat_Content  Outlet_Location_Type
# LF                Tier 1                    84
#                   Tier 2                    95
#                   Tier 3                   137
# Low Fat           Tier 1                  1426
#                   Tier 2                  1679
#                   Tier 3                  1984
# Regular           Tier 1                   813
#                   Tier 2                   940
#                   Tier 3                  1136
# low fat           Tier 1                    30
#                   Tier 2                    35
#                   Tier 3                    47
# reg               Tier 1                    35
#                   Tier 2                    36
#                   Tier 3                    46
# dtype: int64

# %%
import pandas as pd
data = pd.read_csv('Train.csv') 
print (data)
test= data.groupby(['Item_Fat_Content','Outlet_Location_Type'])
test.size()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
import numpy as np
from random import sample
rindex = np.array(sample(range(len(data)), 5))
dfr = data.loc[rindex]
print (dfr)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1942           FDC35        7.435          Low Fat         0.122838
# 3597           DRI01        7.970          Low Fat         0.000000
# 2109           FDU55          NaN          Low Fat         0.035737
# 1716           NCG07       12.300          Low Fat         0.052458
# 98             NCP18          NaN          Low Fat         0.028460
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1942          Starchy Foods  208.7638            OUT046
# 3597            Soft Drinks  173.7422            OUT045
# 2109  Fruits and Vegetables  260.6278            OUT027
# 1716              Household  188.7530            OUT013
# 98                Household  149.9708            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 1942                       1997       Small               Tier 1
# 3597                       2002         NaN               Tier 2
# ...

# %%
test= data.groupby(['Item_Type'])
test.describe()
# Out:
#                       Item_Weight                                        \
#                             count       mean       std    min       25%
# Item_Type
# Baking Goods                536.0  12.277108  4.773622  4.880   8.23500
# Breads                      204.0  11.346936  4.440540  4.635   7.12875
# Breakfast                    89.0  12.768202  5.038131  6.425   8.06000
# Canned                      539.0  12.305705  4.586564  4.615   8.11500
# Dairy                       566.0  13.426069  4.686532  4.805   9.27750
# Frozen Foods                718.0  12.867061  4.507383  4.555   8.93500
# Fruits and Vegetables      1019.0  13.224769  4.575275  5.460   9.19500
# Hard Drinks                 183.0  11.400328  4.239144  4.610   8.26000
# Health and Hygiene          430.0  13.142314  4.512313  5.175   9.69500
# Household                   759.0  13.384736  4.998845  5.030   8.69500
# Meat                        337.0  12.817344  4.670812  5.150   9.30000
# ...

# %%
rem_dup=data.drop_duplicates(['Item_Type', 'Item_Fat_Content'])
print (rem_dup)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 1              DRC01         5.92          Regular         0.019278
# 2              FDN15        17.50          Low Fat         0.016760
# 3              FDX07        19.20          Regular         0.000000
# 4              NCD19         8.93          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 3480           FDY47         8.60              reg         0.054706
# 4758           FDN13        18.60               LF         0.151932
# 4894           FDJ45        17.75          low fat         0.073560
# 5633           DRC36        13.00              reg         0.044976
# 8380           FDI19        15.10          low fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data.isnull()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...
